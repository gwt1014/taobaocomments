# %%
import pandas as pd
from pandas import DataFrame
from bs4 import BeautifulSoup
import requests
import json
import re
from multiprocessing.dummy import Pool
import random
import time
import math

# %%
#淘宝和天猫的商品链接
init_itemurl_tmall = 'https://detail.tmall.com/item.htm?id={}'
init_itemurl_taobao = 'https://item.taobao.com/item.htm?id={}'

# %%
#淘宝和天猫的 搜索页面
init_searchurl_taobao ='https://s.taobao.com/search?'

# %%
#淘宝和天猫的评价链接
init_commenturl_taobao = 'https://rate.taobao.com/feedRateList.htm?'
init_commenturl_tmall  =  'https://rate.tmall.com/list_detail_rate.htm?spuId=843588383&sellerId=2631451752&append=0&tagId=&posi=&picture=&needFold=0'

# %%
#请求头、
headers={
       'accept': '*/*',
        'accept-encoding': 'gzip, deflate, br',
        'accept-language': 'zh-CN,zh;q=0.9',
        'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/67.0.3396.62 Safari/537.36'
        }

# %% [markdown]
# #  获取搜索页中的商品url或者商品id

# %% [markdown]
# ## 淘宝的搜索页
# 会包含天猫的商品，需要把商品连接找然后区分是淘宝还是天猫的。
#
#
# sort设置
# - default 默认
# - sale-desc 销量从高到低
# - credit-desc 信用从高到低
# - price-desc 价格从高到低
# - price-asc 价格从低到高
# - total-asc 总价从低到高
# - total-desc总价从高到低

# %%
def getitemurls_taobao(target,sort='sale-desc',maxpage=1):
    itemurls = {}
    itemurl_taobao = []
    itemurl_tmall = []
    for page in range(0,maxpage):
        params = {
                    'q' : target,
                    'sort' : sort,
                    's' : str(44*(page))
        }
        res = requests.get(init_searchurl_taobao,params=params,headers=headers)
        ids = re.findall('"nid":"(.*?)","category"',res.text,re.S)
        urls = re.findall('"detail_url":"//(.*?)","view_price"',res.text,re.S)
#        print(len(ids))
#        print(len(urls))
        if len(ids) == 0:
            print('被干了这次不算')
        info = dict(ids = ids , urls=urls)
        for i in range(0,len(ids)):
        #由于淘宝页面返回的URL是带//OOOC3这种乱码的，所以url只是看一下到底是淘宝还是天猫，并不作为真正的url传回去
        #返回的URL是用init_itemurl拼出来的
            if 'tmall' in info['urls'][i]:
                itemurl_tmall.append(init_itemurl_tmall.format(info['ids'][i]))
            elif 'taobao' in info['urls'][i]:
                itemurl_taobao.append(init_itemurl_taobao.format(info['ids'][i]))  
#        print("稍等一下")
        time.sleep(random.randint(0,1))
    itemurls['tmall'] = itemurl_tmall
    itemurls['taobao'] = itemurl_taobao
    print('共有商品%d个，其中淘宝%d个，天猫%d个'%((len(itemurl_tmall)+len(itemurl_taobao)),len(itemurl_taobao),len(itemurl_tmall)))
    return itemurls

# %% [markdown]
# ## 天猫的搜索页 还不好使

# %% [markdown]
# #天猫的搜索链接，sort关键字 综合g 销量d 人气rq 价格（低-高）p( 高-低)pd
# init_searchurl_tmall = 'https://list.tmall.com/search_product.htm?'sort=d&q='

# %%
#找商品id列表及评论url列表
def getitemurls_tmall(target,sort='d'):
    itemulrs = []
    for page in range(1,max_page+1):
        url ='https://s.taobao.com/search?q='+target+itemsort+'&s='+str(44*(page-1))
        res = requests.get(url)
        itemid = re.findall('"nid":"(.*?)","category"',res.text,re.S)
        for i in itemid:
            itemulrs.append(init_itemurl.format(i))
    print('已获得%d条商品列表'%len(itemulrs))
    return itemulrs

# %% [markdown]
# # 获取评论

# %% [markdown]
#  先做一个总的函数，用来区分需要获得评论的物品是淘宝的还是天猫的，然后分别做两个小函数去爬取评论

# %%
def getcomments(itemurls):
# 分别取出淘宝和天猫的商品链接
    urls_taobao = itemurls['taobao']
    urls_tmall = itemurls['tmall']
#爬淘宝评论
    result_taobao = []
    for i in range(0,len(urls_taobao)):
        result_taobao.append(getcomments_taobao(urls_taobao[i]))
    taobao = pd.concat(result_taobao,axis=0,ignore_index=True)
#爬天猫评论        
    result_tmall = []
    for i in range(0,len(urls_tmall)):        
        result_tmall.append(getcomments_tmall(urls_tmall[i]))
    tmall = pd.concat(result_tmall,axis=0,ignore_index=True)
#拼在一起
    comments = taobao.merge(tmall,how='outer')
    return comments

# %% [markdown]
# ## 获取淘宝的评论

# %%
def getcomments_taobao(urls_taobao):
    #先拿到商品ID
    itemid = re.findall('id=(\d+)',urls_taobao)[0]
    #获取总评论数，评论页数
        #先拼出来评论的第一页
    t = str(time.time()*1000).split('.')
    params = {
            'currentPageNum':1, 
             'auctionNumId': itemid, 
             '_ksTS':'%s_%s' % (t[0], t[1]) ,
             'callback': 'jsonp_tbcrate_reviews_list',
     #       'ua':'098%23E1hvj9vRvPOvUpCkvvvvvjiPPszUtj1nR2cUzjthPmPhzjDPRFspzjrPR2qWzjlEPFyCvvBvpvvvRphvChCvvvmrvpvbpyn3ChGvpV9sZXVjvpvhphhvvvGCvvpvvvvvvphvCyCCvvvvvvyCvh1hob6vI19anVQEfwAK5kx%2FwAT%2BD40fjLhiHWF9Vt3%2BVkYVyOvO5onmWl4vgC6tExhlBqev%2B4lApB691E7XHkyZwySvtCOqb6OyCW2%2BuphvmhCvCEHhn5hrkphvCyEmmvpfeqyCvm3vpvvvvvCvphCvjvUvvhPQphvwv9vvBj1vpCQmvvChxhCvjvUvvhBZRphvChCvvvm5vpvhphvhHvwCvvNwzHi4z6jN9phv2nQG4VM%2FzYswzVL279%3D%3D',
                'folded': 0,
            'pageSize':'20',
            'hasSku':'false',
            'orderType':'sort_weight'
    }
    res = requests.get(init_commenturl_taobao,params=params,headers=headers)
    jc = json.loads(re.findall(r'{.*}',res.text)[0])
    totcom = jc['total']
    maxpage = min(math.ceil(totcom/20),251)
    print('\r    总评论%d条，可获取%d页（淘宝最大251页）'%(totcom,maxpage))  
    pagelist = list(range(1,maxpage+1))
    # 设置个info列表，每一页的信息为一个元素
    info = []
    geteachpagecom_taobao(itemid,pagelist,info)
    itemcomments = []
    #   把info这个list的每个dataframe拼成一个dataframe
    for i in range(0,len(info)):
        itemcomments = pd.concat(info,axis = 0 ,ignore_index=True)
    return itemcomments

# %%
def geteachpagecom_taobao(itemid,pagelist,info):
    #设置一个banlist，把被干掉的页面存下来，然后再给自己
    banlist = []
    for page in pagelist:
    #for page in range(1,maxpage+1):
        t = str(time.time()*1000).split('.')
        params = {
                'currentPageNum':page, 
                 'auctionNumId': itemid, 
                 '_ksTS':'%s_%s' % (t[0], t[1]) ,
                 'callback': 'jsonp_tbcrate_reviews_list',
         #       'ua':'098%23E1hvj9vRvPOvUpCkvvvvvjiPPszUtj1nR2cUzjthPmPhzjDPRFspzjrPR2qWzjlEPFyCvvBvpvvvRphvChCvvvmrvpvbpyn3ChGvpV9sZXVjvpvhphhvvvGCvvpvvvvvvphvCyCCvvvvvvyCvh1hob6vI19anVQEfwAK5kx%2FwAT%2BD40fjLhiHWF9Vt3%2BVkYVyOvO5onmWl4vgC6tExhlBqev%2B4lApB691E7XHkyZwySvtCOqb6OyCW2%2BuphvmhCvCEHhn5hrkphvCyEmmvpfeqyCvm3vpvvvvvCvphCvjvUvvhPQphvwv9vvBj1vpCQmvvChxhCvjvUvvhBZRphvChCvvvm5vpvhphvhHvwCvvNwzHi4z6jN9phv2nQG4VM%2FzYswzVL279%3D%3D',
                    'folded': 0,
                'pageSize':'20',
                'hasSku':'false',
                'orderType':'sort_weight'
        }
        res = requests.get(init_commenturl_taobao,params=params,headers=headers)
        
        jc = json.loads(re.findall(r'{.*}',res.text)[0])
        if 'comments' in jc:
            users = [i['user']['nick'] for i in jc['comments']]
            rateDate = [i['date'] for i in jc['comments']]
            rateContent = [i['content'] for i in jc['comments']]
            rate = [i['rate'] for i in jc['comments']] #评价 好评中评差评，天猫没有
            appendComment_content = [] #追评内容
            # appendComment_commentTime = [] #追评时间 淘宝是没有的
            appendComment_days = [] #隔了几天追评
            for append in jc['comments']:
                if append['append'] == None:
                    appendComment_content.append(None)
                    appendComment_days.append(None)
                else :
                    appendComment_content.append(append['append']['content'])
                    appendComment_days.append(append['append']['dayAfterConfirm'])
            info.append(pd.DataFrame(dict(rateDate=rateDate,
                                                      users=users,
                                                      rateContent=rateContent,
                                                      rate = rate,
                                                      appendComment_content=appendComment_content,
                                                      #appendComment_commentTime=appendComment_commentTime,
                                                      appendComment_days=appendComment_days,
                                                      source = 'taobao'
                                                     ))) 
            print('\r    第%2d/%2d页 '%(page,len(pagelist)),end='')
        else:
                print('被干掉了等一等')
                banlist.append(eachpage)
                time.sleep(random.uniform(1,6))
    if len(banlist) !=0:
    #        print('有%d页没搞定'%len(banlist))
        info.append(geteachpagecom_taobao(itemid,banlist,info))
    else:
        #如果执行到这里 那就是都搞定了 开始整理数据       
        #开始保存数据，这个可以先放在外面
        #print('全都搞定')
        return info

# %% [markdown]
# ## 获取天猫的评论

# %%
#获取单一商品评论的函数，内部会调用一个获取商品多页评论的递归函数
# 传入的就是这个商品URL
def getcomments_tmall(itemurl):
    #先拿到商品ID
    itemid = re.findall('id=(\d+)',itemurl)[0]
    #获取总评论数，评论页数
        #先拼出来评论的第一页
    t = str(time.time()*1000).split('.')
    params = {
            'currentPage':1,
             'itemId': itemid,
             '_ksTS': '%s_%s' % (t[0], t[1]),
             'callback': 'jsonp%s' %(int(t[1])+1),
             'content':1,
             'order':3 # order = 3 是默认顺序 order=1是按时间排序
            }
    
    res = requests.get(init_commenturl_tmall,params=params)
    jc = json.loads(re.findall(r'{.*}',res.text)[0])
    ## 这里也是有可能被淘宝干掉。。。。。
    totcom = jc['rateDetail']['paginator']['items']
    maxpage = min(jc['rateDetail']['paginator']['lastPage'],99) # 最大是99
    print('\r    总评论%d条，可获取%d页(天猫最多99页)'%(totcom,maxpage))
    #有了最大页数，就做一个递归函数把最大页数里面所有的都爬下来
    pagelist = list(range(1,maxpage+1))
# 设置个info列表，每一页的信息为一个元素
    info = []

    geteachpagecom_tmall(itemid,pagelist,info)
#    return info

    itemcomments = []
#   把info这个list的每个dataframe拼成一个dataframe
    for i in range(0,len(info)):
        itemcomments = pd.concat(info,axis = 0 ,ignore_index=True)
    return  itemcomments

# %%
# 这个是天猫的
def geteachpagecom_tmall(itemid,pagelist,info):
#设置一个banlist，把被干掉的页面存下来，然后再给自己
    banlist = []
    for eachpage in pagelist:
        t = str(time.time()*1000).split('.')
        params = {
                'currentPage':eachpage,
                 'itemId': itemid,
                 '_ksTS': '%s_%s' % (t[0], t[1]),
                 'callback': 'jsonp%s' %(int(t[1])+1),
                 'content':1
                }
        res = requests.get(init_commenturl_tmall,headers=headers,params=params)
        jc = json.loads(re.findall(r'{.*}',res.text)[0])
        
# 获取评论信息
        users = [] #用户id
        rateDate = [] #评论时间
        rateContent = [] #评论内容
        if 'rateDetail' in jc:
            users = [i['displayUserNick'] for i in jc['rateDetail']['rateList']]
            rateDate = [i['rateDate'] for i in jc['rateDetail']['rateList']]
            rateContent = [i['rateContent'] for i in jc['rateDetail']['rateList']]
# 获取追评信息
            appendComment = [i['appendComment'] for i in jc['rateDetail']['rateList']]
            appendComment_content = [] #追评内容
            appendComment_commentTime = [] #追评时间
            appendComment_days = [] #隔了几天追评
            for i in appendComment:
                if type(i)==dict:
                    appendComment_content.append(i['content'])
                    appendComment_commentTime.append(i['commentTime'])
                    appendComment_days.append(i['days'])
                else:
                    appendComment_content.append(None)
                    appendComment_commentTime.append(None)
                    appendComment_days.append(None)
            info.append(pd.DataFrame(dict(rateDate=rateDate,
                                          users=users,
                                          rateContent=rateContent,
                                          appendComment_content=appendComment_content,
                                          appendComment_commentTime=appendComment_commentTime,
                                          appendComment_days=appendComment_days,
                                          source = 'tmall'
                                         ))) 
#            info.append(dict(comments=comments,users=users))
            print('\r    第%2d/%2d页 '%(eachpage,len(pagelist)),end='')
        else:
            print('被干掉了等一等')
            banlist.append(eachpage)
            time.sleep(random.uniform(1,6))
    if len(banlist) !=0:
#        print('有%d页没搞定'%len(banlist))
        info.append(geteachpagecom(itemid,banlist,info))
    else:
        #如果执行到这里 那就是都搞定了 开始整理数据       
        #开始保存数据，这个可以先放在外面
#        print('全都搞定')
        return info

# %% [markdown]
# # 测试用代码

# %% [markdown]
# sort设置
# - default 默认
# - sale-desc 销量从高到低
# - credit-desc 信用从高到低
# - price-desc 价格从高到低
# - price-asc 价格从低到高
# - total-asc 总价从低到高
# - total-desc总价从高到低

# %%
# 获取商品链接
target= '行车记录仪'
itemurls = getitemurls_taobao(target,maxpage=2,sort='sale-desc ')
urls_taobao = itemurls['taobao']
urls_tmall = itemurls['tmall']
# Out:
# 共有商品88个，其中淘宝11个，天猫77个

# %%
#弄出个测试dict 要不然直接轮有点太多了
texturls = {}
texturls['taobao'] = itemurls['taobao']
texturls['tmall'] = itemurls['tmall']
texturls
# Out:
# {'taobao': ['https://item.taobao.com/item.htm?id=566147524797',
#   'https://item.taobao.com/item.htm?id=572608923530',
#   'https://item.taobao.com/item.htm?id=569479613632',
#   'https://item.taobao.com/item.htm?id=569574390163',
#   'https://item.taobao.com/item.htm?id=566106515034',
#   'https://item.taobao.com/item.htm?id=571361192933',
#   'https://item.taobao.com/item.htm?id=566232402210',
#   'https://item.taobao.com/item.htm?id=572591975548',
#   'https://item.taobao.com/item.htm?id=568413568830',
#   'https://item.taobao.com/item.htm?id=572365800701',
#   'https://item.taobao.com/item.htm?id=571498175776'],
#  'tmall': ['https://detail.tmall.com/item.htm?id=559479627099',
#   'https://detail.tmall.com/item.htm?id=563607030343',
#   'https://detail.tmall.com/item.htm?id=548029882169',
#   'https://detail.tmall.com/item.htm?id=565699560376',
#   'https://detail.tmall.com/item.htm?id=559022967045',
#   'https://detail.tmall.com/item.htm?id=568555293239',
#   'https://detail.tmall.com/item.htm?id=569229565972',
#   'https://detail.tmall.com/item.htm?id=541440852748',
#   'https://detail.tmall.com/item.htm?id=567708019433',
#   'https://detail.tmall.com/item.htm?id=567089354448',
#   'https://detail.tmall.com/item.htm?id=558984636573',
#   'https://detail.tmall.com/item.htm?id=564415875899',
#   'https://detail.tmall.com/item.htm?id=566333229820',
#   'https://detail.tmall.com/item.htm?id=562554411711',
#   'https://detail.tmall.com/item.htm?id=567652930879',
#   'https://detail.tmall.com/item.htm?id=562520752276',
#   'https://detail.tmall.com/item.htm?id=565771164693',
#   'https://detail.tmall.com/item.htm?id=569875885405',
#   'https://detail.tmall.com/item.htm?id=562279756255',
#   'https://detail.tmall.com/item.htm?id=555301848645',
#   'https://detail.tmall.com/item.htm?id=545452858724',
#   'https://detail.tmall.com/item.htm?id=522053614639',
#   'https://detail.tmall.com/item.htm?id=45889296831',
#   'https://detail.tmall.com/item.htm?id=549059514299',
#   'https://detail.tmall.com/item.htm?id=569695396670',
#   'https://detail.tmall.com/item.htm?id=531965481898',
#   'https://detail.tmall.com/item.htm?id=561815465309',
#   'https://detail.tmall.com/item.htm?id=567445511874',
#   'https://detail.tmall.com/item.htm?id=571883859814',
#   'https://detail.tmall.com/item.htm?id=545473483441',
#   'https://detail.tmall.com/item.htm?id=538978191837',
#   'https://detail.tmall.com/item.htm?id=530240389459',
coms_taobao =[]
coms_tmall = []

pool = Pool(8)
time3 =time.time()
coms_taobao = pool.map(getcomments_taobao,texturls['taobao'])
coms_tmall = pool.map(getcomments_tmall,texturls['tmall'])
pool.close()
pool.join()

time4 =time.time()
print(str(time4-time3))
# Out:
#     总评论5920条，可获取251页（淘宝最大251页）
#     总评论1760条，可获取88页（淘宝最大251页）
#     总评论377条，可获取19页（淘宝最大251页）
#     总评论1909条，可获取96页（淘宝最大251页）
#     总评论710条，可获取36页（淘宝最大251页）
#     总评论1259条，可获取63页（淘宝最大251页）
#     总评论2883条，可获取145页（淘宝最大251页）
#     总评论17215条，可获取251页（淘宝最大251页）
#     总评论1000条，可获取50页（淘宝最大251页）
#     总评论76条，可获取4页（淘宝最大251页）
#     总评论299条，可获取15页（淘宝最大251页）
#     总评论3213条，可获取99页(天猫最多99页)
#     总评论3841条，可获取99页(天猫最多99页)
#     总评论1124条，可获取57页(天猫最多99页)
#     总评论5941条，可获取99页(天猫最多99页)
#     总评论2836条，可获取99页(天猫最多99页)
#     总评论4903条，可获取99页(天猫最多99页)
#     总评论43977条，可获取99页(天猫最多99页)
#     总评论94973条，可获取99页(天猫最多99页)
#     总评论7225条，可获取99页(天猫最多99页)
#     总评论18045条，可获取99页(天猫最多99页)
#     总评论25772条，可获取99页(天猫最多99页)
#     总评论23518条，可获取99页(天猫最多99页)
#     总评论5858条，可获取99页(天猫最多99页)
#     总评论10566条，可获取99页(天猫最多99页)
#     总评论22272条，可获取99页(天猫最多99页)
#     总评论43478条，可获取99页(天猫最多99页)
#     总评论645条，可获取33页(天猫最多99页)
#     总评论785条，可获取40页(天猫最多99页)
#     总评论4199条，可获取99页(天猫最多99页)
#     总评论5300条，可获取99页(天猫最多99页)
#     总评论4847条，可获取99页(天猫最多99页)
#     总评论2189条，可获取99页(天猫最多99页)
#     总评论4110条，可获取99页(天猫最多99页)
#     总评论96774条，可获取99页(天猫最多99页)
#     总评论1085条，可获取55页(天猫最多99页)
#     总评论42107条，可获取99页(天猫最多99页)
#     总评论8990条，可获取99页(天猫最多99页)
#     总评论9612条，可获取99页(天猫最多99页)
#     总评论2646条，可获取99页(天猫最多99页)
#     总评论1388条，可获取70页(天猫最多99页)
#     总评论1145条，可获取58页(天猫最多99页)
#     总评论1901条，可获取96页(天猫最多99页)
#     总评论3108条，可获取99页(天猫最多99页)
#     总评论18075条，可获取99页(天猫最多99页)
#     总评论8655条，可获取99页(天猫最多99页)
#     总评论1054条，可获取53页(天猫最多99页)
#     总评论433条，可获取22页(天猫最多99页)
#     总评论32066条，可获取99页(天猫最多99页)
#     总评论7674条，可获取99页(天猫最多99页)
#     总评论2402条，可获取99页(天猫最多99页)
#     总评论773条，可获取39页(天猫最多99页)
#     总评论20269条，可获取99页(天猫最多99页)
#     总评论13535条，可获取99页(天猫最多99页)
#     总评论24618条，可获取99页(天猫最多99页)
#     总评论1364条，可获取69页(天猫最多99页)
#     总评论7750条，可获取99页(天猫最多99页)
#     总评论1443条，可获取73页(天猫最多99页)
#     总评论2200条，可获取99页(天猫最多99页)
#     总评论7161条，可获取99页(天猫最多99页)
#     总评论13937条，可获取99页(天猫最多99页)
#     总评论11910条，可获取99页(天猫最多99页)
#     总评论962条，可获取49页(天猫最多99页)
#     总评论764条，可获取39页(天猫最多99页)
#     总评论591条，可获取30页(天猫最多99页)
#     总评论1681条，可获取85页(天猫最多99页)
#     总评论2858条，可获取99页(天猫最多99页)
#     总评论2871条，可获取99页(天猫最多99页)
#     总评论1287条，可获取65页(天猫最多99页)
#     总评论2644条，可获取99页(天猫最多99页)
#     总评论1687条，可获取85页(天猫最多99页)
#     总评论1484条，可获取75页(天猫最多99页)
#     总评论2359条，可获取99页(天猫最多99页)
#     总评论483条，可获取25页(天猫最多99页)
#     总评论6280条，可获取99页(天猫最多99页)
#     第16/25页 可获取36页(天猫最多99页)
#     总评论5865条，可获取99页(天猫最多99页)
#     总评论3966条，可获取99页(天猫最多99页)
#     总评论797条，可获取40页(天猫最多99页)
#     总评论1213条，可获取61页(天猫最多99页)
#     总评论7678条，可获取99页(天猫最多99页)
#     总评论3302条，可获取99页(天猫最多99页)
#     总评论5445条，可获取99页(天猫最多99页)
#     总评论7660条，可获取99页(天猫最多99页)
#     总评论2794条，可获取99页(天猫最多99页)
#     总评论10919条，可获取99页(天猫最多99页)
#     总评论469条，可获取24页(天猫最多99页)
#     总评论1141条，可获取58页(天猫最多99页)
#     第58/58页 1143.7340178489685

# %%
tb = []
for i in coms_taobao:
    if len(i)!=0:
        tb.append(i)
taobao = pd.concat(tb,axis=0,ignore_index=True)
taobao
# Out:
#                                    appendComment_content  appendComment_days  \
# 0                                                   None                 NaN
# 1      大家看一下他们家的东西有多差一个固定卡槽自己弹出来已固定不住摄像头也一样固定不住开车只要一颠...                59.0
# 2      宝贝收到了，包装精美，我一个人安装的花了10分钟，安装简单，从外观上看记录仪小巧精致，奢华材...                32.0
# 3      用了一段时间，很不错，记录仪确实给力，一家人出了一趟远门一路上报的非常详细&nbsp;沿路的...                16.0
# 4      宏曼的牌子，真的是一款很不错的记录仪，这个跟想象的一样，非常满意，功能齐全，操作方便，质量非...                38.0
# 5                                                   None                 NaN
# 6      宝贝收到了，非常不错，质量也很好，值得购买，款式很漂亮，推荐大家购买，屏幕很清晰。款式很不错...                46.0
# 7      不错不错，现在开车上路，没个行车记录仪真是不行。眼睛看指示牌都看的眼花缭乱，有语音播报就不用...                17.0
# 8      很满意，非常好的卖家，发现崩扣少了一个，立马就帮我补发了一对过来。记录仪也很好用，之前还担心...                29.0
# 9      收到货了，图片和实物没有啥差距，本来不怎么相信网上的东西，便宜的买还行，这种本来就是抱着试一...                28.0
# 10     很早就想买个行车记录仪，有一次开车因为没有记录仪吃亏了，无责反被讹了，吸取教训买了记录仪。白...                29.0
# 11     我买这个的原因性价比很高，起动车时，自动开机了，操作很简便，是我想要的宝贝,安装也很牢固，机...                42.0
# 12     安装的时候问了客服怎么安装，之后发了安装视频给我，安装特别简单，半个小时都没有就安装好了，特...                40.0
# 13     说说用完后的感受，很不错的行车记录仪，24小时都可以监控了，价格不贵又实惠，车都买了，这点钱...                13.0
# 14     记录仪收到一段时间了， 收到后就立刻安装了，按商家提供的安装方便安装，安完效果不错，比较清晰...                16.0
# 15                                                  None                 NaN
# 16     物流快快的，总体很不错，记录仪收到了，买给自家用的，刚买的新车，老公说要装个记录仪安全些。叫...                15.0
# 17     记录仪收到了，店家发货用的快递配送很及时，非常满意。简单安装已经试试用了好几天了，一直在观察...                16.0
# 18     辣鸡&hellip;电子狗反应嗷嗷迟钝   过了探头100米以后才报车速？  我用你报？  ...                53.0
# 19     挺满意的!清晰度可以，性价比高，满意！ 以前我基本都是默认好评，很少评价，除了让我非常满意的...                80.0
# 20                                                  None                 NaN
# 21                                                  None                 NaN
# 22                                                  None                 NaN
# 23                                                  None                 NaN
# 24     物流很快，包装也很好。收到货后，迫不及待的拆开看看，物品很好看，附件也齐全。过了两天，天气好...                50.0
# 25                                                  None                 NaN
# 26                                                  None                 NaN
# 27                                                  None                 NaN
# 28                                                  None                 NaN
# 29                                                  None                 NaN
# ...                                                  ...                 ...
# 20283                                               None                 NaN
# 20284                                               None                 NaN
# 20285                                               None                 NaN
# 20286                                               None                 NaN
# 20287                                               None                 NaN
# 20288                                               None                 NaN
# 20289                                               None                 NaN
# 20290                                               None                 NaN
# 20291                                               None                 NaN
# 20292                                               None                 NaN
# 20293                                               None                 NaN
# 20294                                               None                 NaN
# 20295                                               None                 NaN
# 20296                                               None                 NaN
# 20297                                               None                 NaN
# 20298                                               None                 NaN
# 20299                                               None                 NaN
# 20300                                               None                 NaN
# 20301                                               None                 NaN
# 20302                                               None                 NaN
# 20303                                               None                 NaN
# 20304                                               None                 NaN
# 20305                                               None                 NaN
# 20306                                               None                 NaN
# 20307                                               None                 NaN
# 20308                                               None                 NaN
# 20309                                               None                 NaN
# 20310                                               None                 NaN
# 20311                                               None                 NaN
# 20312                                               None                 NaN
#
#       rate                                        rateContent  \
# 0        1            78元能买个行车记录仪，很不错了！非常容易安装，几分钟的事情就搞掂了，值得推荐
# 1       -2                                        15天内买家未作出评价
# 2        1                                 评价方未及时做出评价,系统默认好评!
# 3        1                                         此用户没有填写评价。
# 4        1                                         此用户没有填写评价。
# 5        1                         试了试还不错，快递挺快的，客服非常好，后期用用在评论
# 6        1                                 评价方未及时做出评价,系统默认好评!
# 7        1                                         此用户没有填写评价。
# 8        1                                         此用户没有填写评价。
# 9        1                                 评价方未及时做出评价,系统默认好评!
# 10       1                                         此用户没有填写评价。
# 11       1                                 评价方未及时做出评价,系统默认好评!
# 12       1                                 评价方未及时做出评价,系统默认好评!
# 13       1                                         此用户没有填写评价。
# 14       1                                         此用户没有填写评价。
# 15       1  昨天收到宝贝，因我的车只有一个车冲点火器，花了点时间改成USB插头，今天花了一上午，自己动手...
# 16       1                                         此用户没有填写评价。
# 17       1                                 评价方未及时做出评价,系统默认好评!
# 18       1                                 评价方未及时做出评价,系统默认好评!
# 19       1                                 评价方未及时做出评价,系统默认好评!
# 20       1  记录仪收到好几天了，送了好多东西。外观漂亮大方，大气，摄像头很清晰，而且用了这么多天，没有发...
# 21       1  快递小哥送货速度快，包裹的严严实实没有任何破损，机器本身没得说，高请，功能还很全面，晚上拍摄...
# 22       1  一收到货立马就安装起来了，嗯确实容易上手，很好安装。装好之后特意开出去转悠了一圈，图像清晰，...
# 23       1       东西很好，显示很清晰。效果的非常的棒棒的。屏幕也可以非常到位。下次在来。谢谢客服小姐姐。
# 24       1                                         此用户没有填写评价。
# 25       1  物流非常快，打开安装非常方便，插上卡插上电就可以使用，这个图片是阴天拍摄的，图像还是非常清楚...
# 26       1              东西很好用，很不错的价格的行车记录仪，这个价格已经很好了，下次再次合作吧。
# 27       1  快递小哥送货速度快，包裹的严严实实没有任何破损，机器本身没得说，高请，功能还很全面，晚上拍摄...
# 28       1                      看看上去做工还不错，还没有装，比实体店便宜不少。期待好用。
# 29       1             东西很不错，24小时停车监控，安装起来也很方便，东西很好！好评！画面也很清晰
# ...    ...                                                ...
# 20283    1                     高清影像，前后双录，屏幕也很大，很喜欢，以后就不怕碰瓷的了。
# 20284    1                                               映像清晰
# 20285    1                                         此用户没有填写评价。
# 20286    1                                         此用户没有填写评价。
# 20287    1                                         此用户没有填写评价。
# 20288    1                                 评价方未及时做出评价,系统默认好评!
# 20289    1                                 评价方未及时做出评价,系统默认好评!
# 20290    1                                         此用户没有填写评价。
# 20291    1                                         此用户没有填写评价。
# 20292    1                                 评价方未及时做出评价,系统默认好评!
# 20293    1                                 评价方未及时做出评价,系统默认好评!
# 20294    1                                         此用户没有填写评价。
# 20295    1                                 评价方未及时做出评价,系统默认好评!
# 20296    1                                         此用户没有填写评价。
# 20297    1                                         此用户没有填写评价。
# 20298    1                                 评价方未及时做出评价,系统默认好评!
# 20299    1                                 评价方未及时做出评价,系统默认好评!
# 20300    1                                         此用户没有填写评价。
# 20301    1                                         此用户没有填写评价。
# 20302    1                                 评价方未及时做出评价,系统默认好评!
# 20303    1                                 评价方未及时做出评价,系统默认好评!
# 20304    1                                 评价方未及时做出评价,系统默认好评!
# 20305    1                                 评价方未及时做出评价,系统默认好评!
# 20306    1                                 评价方未及时做出评价,系统默认好评!
# 20307    1                                 评价方未及时做出评价,系统默认好评!
# 20308    1                                 评价方未及时做出评价,系统默认好评!
# 20309    1                                 评价方未及时做出评价,系统默认好评!
# 20310    1                                         此用户没有填写评价。
# 20311    1                                         此用户没有填写评价。
# 20312    1                                         此用户没有填写评价。
#
#                 rateDate  source  users
# 0      2018年07月06日 10:44  taobao  d***y
# 1                         taobao  t***2
# 2      2018年06月21日 20:20  taobao  g***1
# 3      2018年06月25日 18:43  taobao  c***f
# 4      2018年06月01日 23:23  taobao  t***6
# %%
com2 = taobao.merge(tmall,how='outer')

# %%
com2
# Out:
#                                     appendComment_content  appendComment_days  \
# 0                                                    None                 NaN
# 1       大家看一下他们家的东西有多差一个固定卡槽自己弹出来已固定不住摄像头也一样固定不住开车只要一颠...                59.0
# 2       宝贝收到了，包装精美，我一个人安装的花了10分钟，安装简单，从外观上看记录仪小巧精致，奢华材...                32.0
# 3       用了一段时间，很不错，记录仪确实给力，一家人出了一趟远门一路上报的非常详细&nbsp;沿路的...                16.0
# 4       宏曼的牌子，真的是一款很不错的记录仪，这个跟想象的一样，非常满意，功能齐全，操作方便，质量非...                38.0
# 5                                                    None                 NaN
# 6       宝贝收到了，非常不错，质量也很好，值得购买，款式很漂亮，推荐大家购买，屏幕很清晰。款式很不错...                46.0
# 7       不错不错，现在开车上路，没个行车记录仪真是不行。眼睛看指示牌都看的眼花缭乱，有语音播报就不用...                17.0
# 8       很满意，非常好的卖家，发现崩扣少了一个，立马就帮我补发了一对过来。记录仪也很好用，之前还担心...                29.0
# 9       收到货了，图片和实物没有啥差距，本来不怎么相信网上的东西，便宜的买还行，这种本来就是抱着试一...                28.0
# 10      很早就想买个行车记录仪，有一次开车因为没有记录仪吃亏了，无责反被讹了，吸取教训买了记录仪。白...                29.0
# 11      我买这个的原因性价比很高，起动车时，自动开机了，操作很简便，是我想要的宝贝,安装也很牢固，机...                42.0
# 12      安装的时候问了客服怎么安装，之后发了安装视频给我，安装特别简单，半个小时都没有就安装好了，特...                40.0
# 13      说说用完后的感受，很不错的行车记录仪，24小时都可以监控了，价格不贵又实惠，车都买了，这点钱...                13.0
# 14      记录仪收到一段时间了， 收到后就立刻安装了，按商家提供的安装方便安装，安完效果不错，比较清晰...                16.0
# 15                                                   None                 NaN
# 16      物流快快的，总体很不错，记录仪收到了，买给自家用的，刚买的新车，老公说要装个记录仪安全些。叫...                15.0
# 17      记录仪收到了，店家发货用的快递配送很及时，非常满意。简单安装已经试试用了好几天了，一直在观察...                16.0
# 18      辣鸡&hellip;电子狗反应嗷嗷迟钝   过了探头100米以后才报车速？  我用你报？  ...                53.0
# 19      挺满意的!清晰度可以，性价比高，满意！ 以前我基本都是默认好评，很少评价，除了让我非常满意的...                80.0
# 20                                                   None                 NaN
# 21                                                   None                 NaN
# 22                                                   None                 NaN
# 23                                                   None                 NaN
# 24      物流很快，包装也很好。收到货后，迫不及待的拆开看看，物品很好看，附件也齐全。过了两天，天气好...                50.0
# 25                                                   None                 NaN
# 26                                                   None                 NaN
# 27                                                   None                 NaN
# 28                                                   None                 NaN
# 29                                                   None                 NaN
# ...                                                   ...                 ...
# 149653                                               None                 NaN
# 149654                                               None                 NaN
# 149655                                               None                 NaN
# 149656                                               None                 NaN
# 149657                                               None                 NaN
# 149658                                               None                 NaN
# 149659                                               None                 NaN
# 149660                                               None                 NaN
# 149661                                               None                 NaN
# 149662                                               None                 NaN
# 149663                                               None                 NaN
# 149664                                               None                 NaN
# 149665                                               None                 NaN
# 149666                                               None                 NaN
# 149667                                               None                 NaN
# 149668                                               None                 NaN
# 149669                                               None                 NaN
# 149670                                               None                 NaN
# 149671                                               None                 NaN
# 149672                                  安装简单，用起来比较方便，效果不错                 0.0
# 149673                                               None                 NaN
# 149674                                               None                 NaN
# 149675                                               None                 NaN
# 149676                                               None                 NaN
# 149677                                               None                 NaN
# 149678                                               None                 NaN
# 149679                                               None                 NaN
# 149680                                               None                 NaN
# 149681                                               None                 NaN
# 149682                                               None                 NaN
#
#        rate                                        rateContent  \
# 0         1            78元能买个行车记录仪，很不错了！非常容易安装，几分钟的事情就搞掂了，值得推荐
# 1        -2                                        15天内买家未作出评价
# 2         1                                 评价方未及时做出评价,系统默认好评!
# 3         1                                         此用户没有填写评价。
# 4         1                                         此用户没有填写评价。
# 5         1                         试了试还不错，快递挺快的，客服非常好，后期用用在评论
# 6         1                                 评价方未及时做出评价,系统默认好评!
# 7         1                                         此用户没有填写评价。
# 8         1                                         此用户没有填写评价。
# 9         1                                 评价方未及时做出评价,系统默认好评!
# 10        1                                         此用户没有填写评价。
# 11        1                                 评价方未及时做出评价,系统默认好评!
# 12        1                                 评价方未及时做出评价,系统默认好评!
# 13        1                                         此用户没有填写评价。
# 14        1                                         此用户没有填写评价。
# 15        1  昨天收到宝贝，因我的车只有一个车冲点火器，花了点时间改成USB插头，今天花了一上午，自己动手...
# 16        1                                         此用户没有填写评价。
# 17        1                                 评价方未及时做出评价,系统默认好评!
# 18        1                                 评价方未及时做出评价,系统默认好评!
# 19        1                                 评价方未及时做出评价,系统默认好评!
# 20        1  记录仪收到好几天了，送了好多东西。外观漂亮大方，大气，摄像头很清晰，而且用了这么多天，没有发...
# 21        1  快递小哥送货速度快，包裹的严严实实没有任何破损，机器本身没得说，高请，功能还很全面，晚上拍摄...
# 22        1  一收到货立马就安装起来了，嗯确实容易上手，很好安装。装好之后特意开出去转悠了一圈，图像清晰，...
# 23        1       东西很好，显示很清晰。效果的非常的棒棒的。屏幕也可以非常到位。下次在来。谢谢客服小姐姐。
# 24        1                                         此用户没有填写评价。
# 25        1  物流非常快，打开安装非常方便，插上卡插上电就可以使用，这个图片是阴天拍摄的，图像还是非常清楚...
# 26        1              东西很好用，很不错的价格的行车记录仪，这个价格已经很好了，下次再次合作吧。
# 27        1  快递小哥送货速度快，包裹的严严实实没有任何破损，机器本身没得说，高请，功能还很全面，晚上拍摄...
# 28        1                      看看上去做工还不错，还没有装，比实体店便宜不少。期待好用。
# 29        1             东西很不错，24小时停车监控，安装起来也很方便，东西很好！好评！画面也很清晰
# ...     ...                                                ...
# 149653  NaN                                   东西很好，也很实用，下次还会光顾
# 149654  NaN  这个非常好   行车的安全性瞬间提高很多    上次因为停在没有监控的停车位  结果被别人刮...
# 149655  NaN                           正品，安装方便，声音太小不错，图像清晰，放心购买
# 149656  NaN                               非常好。产品非常棒不错很喜欢。性价比很高
