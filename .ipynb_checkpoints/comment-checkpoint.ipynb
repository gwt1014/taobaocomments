# %%
import pandas as pd
from pandas import DataFrame
from bs4 import BeautifulSoup
import requests
import json
import re
from multiprocessing.dummy import Pool
import random
import time
import math

# %%
#淘宝和天猫的商品链接
init_itemurl_tmall = 'https://detail.tmall.com/item.htm?id={}'
init_itemurl_taobao = 'https://item.taobao.com/item.htm?id={}'

# %%
#淘宝和天猫的 搜索页面
init_searchurl_taobao ='https://s.taobao.com/search?'

# %%
#淘宝和天猫的评价链接
init_commenturl_taobao = 'https://rate.taobao.com/feedRateList.htm?'
init_commenturl_tmall  =  'https://rate.tmall.com/list_detail_rate.htm?spuId=843588383&sellerId=2631451752&append=0&tagId=&posi=&picture=&needFold=0'

# %%
#请求头
headers={
       'accept': '*/*',
        'accept-encoding': 'gzip, deflate, br',
        'accept-language': 'zh-CN,zh;q=0.9',
        'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/67.0.3396.62 Safari/537.36'
        }

# %% [markdown]
# #  获取搜索页中的商品url或者商品id

# %% [markdown]
# ## 淘宝的搜索页
# 会包含天猫的商品，需要把商品连接找然后区分是淘宝还是天猫的。
#
#
# sort设置
# - default 默认
# - sale-desc 销量从高到低
# - credit-desc 信用从高到低
# - price-desc 价格从高到低
# - price-asc 价格从低到高
# - total-asc 总价从低到高
# - total-desc总价从高到低

# %%
def getitemurls_taobao(target,sort='sale-desc',maxpage=1):
    itemurls = {}
    itemurl_taobao = []
    itemurl_tmall = []
    for page in range(0,maxpage):
        params = {
                    'q' : target,
                    'sort' : sort,
                    's' : str(44*(page))
        }
        res = requests.get(init_searchurl_taobao,params=params,headers=headers)
        ids = re.findall('"nid":"(.*?)","category"',res.text,re.S)
        urls = re.findall('"detail_url":"//(.*?)","view_price"',res.text,re.S)
#        print(len(ids))
#        print(len(urls))
        if len(ids) == 0:
            print('被干了这次不算')
        info = dict(ids = ids , urls=urls)
        for i in range(0,len(ids)):
        #由于淘宝页面返回的URL是带//OOOC3这种乱码的，所以url只是看一下到底是淘宝还是天猫，并不作为真正的url传回去
        #返回的URL是用init_itemurl拼出来的
            if 'tmall' in info['urls'][i]:
                itemurl_tmall.append(init_itemurl_tmall.format(info['ids'][i]))
            elif 'taobao' in info['urls'][i]:
                itemurl_taobao.append(init_itemurl_taobao.format(info['ids'][i]))  
#        print("稍等一下")
        time.sleep(random.randint(0,1))
    itemurls['tmall'] = itemurl_tmall
    itemurls['taobao'] = itemurl_taobao
    print('共有商品%d个，其中淘宝%d个，天猫%d个'%((len(itemurl_tmall)+len(itemurl_taobao)),len(itemurl_taobao),len(itemurl_tmall)))
    return itemurls

# %% [markdown]
# ## 天猫的搜索页 还不好使

# %% [markdown]
# #天猫的搜索链接，sort关键字 综合g 销量d 人气rq 价格（低-高）p( 高-低)pd
# init_searchurl_tmall = 'https://list.tmall.com/search_product.htm?'sort=d&q='

# %%
#找商品id列表及评论url列表
def getitemurls_tmall(target,sort='d'):
    itemulrs = []
    for page in range(1,max_page+1):
        url ='https://s.taobao.com/search?q='+target+itemsort+'&s='+str(44*(page-1))
        res = requests.get(url)
        itemid = re.findall('"nid":"(.*?)","category"',res.text,re.S)
        for i in itemid:
            itemulrs.append(init_itemurl.format(i))
    print('已获得%d条商品列表'%len(itemulrs))
    return itemulrs

# %% [markdown]
# # 获取评论

# %% [markdown]
#  先做一个总的函数，用来区分需要获得评论的物品是淘宝的还是天猫的，然后分别做两个小函数去爬取评论

# %%
def getcomments(itemurls):
# 分别取出淘宝和天猫的商品链接
    urls_taobao = itemurls['taobao']
    urls_tmall = itemurls['tmall']

#    comments_taobao = getcomments_taobao(urls_taobao)
#    comments_tmall = getcomments_tmall(urls_tmall)
    #comments 
    return comments

# %% [markdown]
# ## 获取淘宝的评论

# %%
def getcomments_taobao(urls_taobao):
    #先拿到商品ID
    itemid = re.findall('id=(\d+)',urls_taobao)[0]
    #获取总评论数，评论页数
        #先拼出来评论的第一页
    t = str(time.time()*1000).split('.')
    params = {
            'currentPageNum':1, 
             'auctionNumId': itemid, 
             '_ksTS':'%s_%s' % (t[0], t[1]) ,
             'callback': 'jsonp_tbcrate_reviews_list',
     #       'ua':'098%23E1hvj9vRvPOvUpCkvvvvvjiPPszUtj1nR2cUzjthPmPhzjDPRFspzjrPR2qWzjlEPFyCvvBvpvvvRphvChCvvvmrvpvbpyn3ChGvpV9sZXVjvpvhphhvvvGCvvpvvvvvvphvCyCCvvvvvvyCvh1hob6vI19anVQEfwAK5kx%2FwAT%2BD40fjLhiHWF9Vt3%2BVkYVyOvO5onmWl4vgC6tExhlBqev%2B4lApB691E7XHkyZwySvtCOqb6OyCW2%2BuphvmhCvCEHhn5hrkphvCyEmmvpfeqyCvm3vpvvvvvCvphCvjvUvvhPQphvwv9vvBj1vpCQmvvChxhCvjvUvvhBZRphvChCvvvm5vpvhphvhHvwCvvNwzHi4z6jN9phv2nQG4VM%2FzYswzVL279%3D%3D',
                'folded': 0,
            'pageSize':'20',
            'hasSku':'false',
            'orderType':'sort_weight'
    }
    res = requests.get(init_commenturl_taobao,params=params,headers=headers)
    jc = json.loads(re.findall(r'{.*}',res.text)[0])
    totcom = jc['total']
    maxpage = min(math.ceil(totcom/20),251)
    print('\r    总评论%d条，可获取%d页（淘宝最大251页）'%(totcom,maxpage))  
    pagelist = list(range(1,maxpage+1))
    # 设置个info列表，每一页的信息为一个元素
    info = []
    geteachpagecom_taobao(itemid,pagelist,info)
    itemcomments = []
    #   把info这个list的每个dataframe拼成一个dataframe
    for i in range(0,len(info)):
        itemcomments = pd.concat(info,axis = 0 ,ignore_index=True)
    return itemcomments

# %%
def geteachpagecom_taobao(itemid,pagelist,info):
    #设置一个banlist，把被干掉的页面存下来，然后再给自己
    banlist = []
    for page in pagelist:
    #for page in range(1,maxpage+1):
        t = str(time.time()*1000).split('.')
        params = {
                'currentPageNum':page, 
                 'auctionNumId': itemid, 
                 '_ksTS':'%s_%s' % (t[0], t[1]) ,
                 'callback': 'jsonp_tbcrate_reviews_list',
         #       'ua':'098%23E1hvj9vRvPOvUpCkvvvvvjiPPszUtj1nR2cUzjthPmPhzjDPRFspzjrPR2qWzjlEPFyCvvBvpvvvRphvChCvvvmrvpvbpyn3ChGvpV9sZXVjvpvhphhvvvGCvvpvvvvvvphvCyCCvvvvvvyCvh1hob6vI19anVQEfwAK5kx%2FwAT%2BD40fjLhiHWF9Vt3%2BVkYVyOvO5onmWl4vgC6tExhlBqev%2B4lApB691E7XHkyZwySvtCOqb6OyCW2%2BuphvmhCvCEHhn5hrkphvCyEmmvpfeqyCvm3vpvvvvvCvphCvjvUvvhPQphvwv9vvBj1vpCQmvvChxhCvjvUvvhBZRphvChCvvvm5vpvhphvhHvwCvvNwzHi4z6jN9phv2nQG4VM%2FzYswzVL279%3D%3D',
                    'folded': 0,
                'pageSize':'20',
                'hasSku':'false',
                'orderType':'sort_weight'
        }
        res = requests.get(init_commenturl_taobao,params=params,headers=headers)
        jc = json.loads(re.findall(r'{.*}',res.text)[0])
        if 'comments' in jc:
            users = [i['user']['nick'] for i in jc['comments']]
            rateDate = [i['date'] for i in jc['comments']]
            rateContent = [i['content'] for i in jc['comments']]
            rate = [i['rate'] for i in jc['comments']] #评价 好评中评差评，天猫没有
            appendComment_content = [] #追评内容
            # appendComment_commentTime = [] #追评时间 淘宝是没有的
            appendComment_days = [] #隔了几天追评
            for append in jc['comments']:
                if append['append'] == None:
                    appendComment_content.append(None)
                    appendComment_days.append(None)
                else :
                    appendComment_content.append(append['append']['content'])
                    appendComment_days.append(append['append']['dayAfterConfirm'])
            info.append(pd.DataFrame(dict(rateDate=rateDate,
                                                      users=users,
                                                      rateContent=rateContent,
                                                      rate = rate,
                                                      appendComment_content=appendComment_content,
                                                      #appendComment_commentTime=appendComment_commentTime,
                                                      appendComment_days=appendComment_days
                                                     ))) 
            print('\r    第%2d/%2d页 '%(page,len(pagelist)),end='')
        else:
                print('被干掉了等一等')
                banlist.append(eachpage)
                time.sleep(random.uniform(1,6))
    if len(banlist) !=0:
    #        print('有%d页没搞定'%len(banlist))
        info.append(geteachpagecom_taobao(itemid,banlist,info))
    else:
        #如果执行到这里 那就是都搞定了 开始整理数据       
        #开始保存数据，这个可以先放在外面
        #print('全都搞定')
        return info

# %% [markdown]
# ## 获取天猫的评论

# %%
#获取单一商品评论的函数，内部会调用一个获取商品多页评论的递归函数
# 传入的就是这个商品URL
def getcomments_tmall(itemurl):
    #先拿到商品ID
    itemid = re.findall('id=(\d+)',itemurl)[0]
    #获取总评论数，评论页数
        #先拼出来评论的第一页
    t = str(time.time()*1000).split('.')
    params = {
            'currentPage':1,
             'itemId': itemid,
             '_ksTS': '%s_%s' % (t[0], t[1]),
             'callback': 'jsonp%s' %(int(t[1])+1),
             'content':1,
             'order':3 # order = 3 是默认顺序 order=1是按时间排序
            }
    
    res = requests.get(init_commenturl_tmall,params=params)
    jc = json.loads(re.findall(r'{.*}',res.text)[0])
    ## 这里也是有可能被淘宝干掉。。。。。
    totcom = jc['rateDetail']['paginator']['items']
    maxpage = jc['rateDetail']['paginator']['lastPage'] # 最大是99
    print('\r    总评论%d条，可获取%d页'%(totcom,maxpage))
    #有了最大页数，就做一个递归函数把最大页数里面所有的都爬下来
    pagelist = list(range(1,maxpage+1))
# 设置个info列表，每一页的信息为一个元素
    info = []

    geteachpagecom_tmall(itemid,pagelist,info)
#    return info

    itemcomments = []
#   把info这个list的每个dataframe拼成一个dataframe
    for i in range(0,len(info)):
        itemcomments = pd.concat(info,axis = 0 ,ignore_index=True)
    return  itemcomments

# %%
# 这个是天猫的
def geteachpagecom_tmall(itemid,pagelist,info):
#设置一个banlist，把被干掉的页面存下来，然后再给自己
    banlist = []
    for eachpage in pagelist:
        t = str(time.time()*1000).split('.')
        params = {
                'currentPage':eachpage,
                 'itemId': itemid,
                 '_ksTS': '%s_%s' % (t[0], t[1]),
                 'callback': 'jsonp%s' %(int(t[1])+1),
                 'content':1
                }
        res = requests.get(init_commenturl_tmall,headers=headers,params=params)
        jc = json.loads(re.findall(r'{.*}',res.text)[0])
        
# 获取评论信息
        users = [] #用户id
        rateDate = [] #评论时间
        rateContent = [] #评论内容
        if 'rateDetail' in jc:
            users = [i['displayUserNick'] for i in jc['rateDetail']['rateList']]
            rateDate = [i['rateDate'] for i in jc['rateDetail']['rateList']]
            rateContent = [i['rateContent'] for i in jc['rateDetail']['rateList']]
# 获取追评信息
            appendComment = [i['appendComment'] for i in jc['rateDetail']['rateList']]
            appendComment_content = [] #追评内容
            appendComment_commentTime = [] #追评时间
            appendComment_days = [] #隔了几天追评
            for i in appendComment:
                if type(i)==dict:
                    appendComment_content.append(i['content'])
                    appendComment_commentTime.append(i['commentTime'])
                    appendComment_days.append(i['days'])
                else:
                    appendComment_content.append(None)
                    appendComment_commentTime.append(None)
                    appendComment_days.append(None)
            info.append(pd.DataFrame(dict(rateDate=rateDate,
                                          users=users,
                                          rateContent=rateContent,
                                          appendComment_content=appendComment_content,
                                          appendComment_commentTime=appendComment_commentTime,
                                          appendComment_days=appendComment_days
                                         ))) 
#            info.append(dict(comments=comments,users=users))
            print('\r    第%2d/%2d页 '%(eachpage,len(pagelist)),end='')
        else:
            print('被干掉了等一等')
            banlist.append(eachpage)
            time.sleep(random.uniform(1,6))
    if len(banlist) !=0:
#        print('有%d页没搞定'%len(banlist))
        info.append(geteachpagecom(itemid,banlist,info))
    else:
        #如果执行到这里 那就是都搞定了 开始整理数据       
        #开始保存数据，这个可以先放在外面
#        print('全都搞定')
        return info

# %%
# 测试用代码
target= 'adas'

itemurls = getitemurls_taobao(target)
urls_taobao = itemurls['taobao']

# %%
# 测试用代码
target= 'adas'

itemurls = getitemurls_taobao(target,maxpage=2)
urls_taobao = itemurls['taobao']
urls_tmall = itemurls['tmall']
# Out:
# 共有商品88个，其中淘宝63个，天猫25个

# %%
result = []
for i in range(0,2):
#    result.append(getcomments_tmall(urls_tmall[i]))
    result.append(getcomments_taobao(urls_taobao[i]))
pd.concat(result,axis=0,ignore_index=True)
# Out:
#     总评论174条，可获取9页（淘宝最大251页）
#     总评论320条，可获取16页（淘宝最大251页）
#     第16/16页
#                                  appendComment_content  appendComment_days  \
# 0                                                 None                 NaN
# 1                                                 None                 NaN
# 2                                                 None                 NaN
# 3                                                 None                 NaN
# 4                                                 None                 NaN
# 5                                                 None                 NaN
# 6                                  装机多** 使用上没问题 清析 好操作                 5.0
# 7                                                 None                 NaN
# 8                                                 None                 NaN
# 9                                                 None                 NaN
# 10                                                None                 NaN
# 11                                                None                 NaN
# 12                                                None                 NaN
# 13                                                None                 NaN
# 14                                                None                 NaN
# 15                                                None                 NaN
# 16                                                None                 NaN
# 17                                                None                 NaN
# 18                                                None                 NaN
# 19                                                None                 NaN
# 20                                  大家千万不要上当了，，东西太垃圾了，                 2.0
# 21                                                None                 NaN
# 22                                                None                 NaN
# 23                                                None                 NaN
# 24                                                None                 NaN
# 25                                                None                 NaN
# 26                                                None                 NaN
# 27                                                None                 NaN
# 28                                                None                 NaN
# 29                                                None                 NaN
# ..                                                 ...                 ...
# 464                                               None                 NaN
# 465                                        店家态度不错，放心购买                 8.0
# 466                                               None                 NaN
# 467                                               None                 NaN
# 468                                              特别清楚，                 0.0
# 469                                               None                 NaN
# 470                                               None                 NaN
# 471                                               None                 NaN
# 472                                               None                 NaN
# 473                                           晚上效果挺不错的                 1.0
# 474                                               None                 NaN
# 475                                           一点都不档视线，                 7.0
# 476                                               None                 NaN
# 477  后视摄像头不是高清的有点遗憾，前摄像头默认不是1080p的，是720p的。有可能是双摄的问题...                46.0
# 478                                               None                 NaN
# 479                                  非常爽，还有右侧盲区监控，特别好用                 0.0
# 480                                               None                 NaN
# 481                                         客服很耐心 解决疑问                 0.0
# 482                                               None                 NaN
# 483                                               None                 NaN
# 484                                               None                 NaN
# 485                                               None                 NaN
# 486                                               None                 NaN
# 487                                               None                 NaN
# 488                                               None                 NaN
# 489                                               None                 NaN
# 490                                               None                 NaN
# 491                                               None                 NaN
# 492                                               None                 NaN
# 493                                               None                 NaN
#
#     rate                                        rateContent  \
# 0      1  宝贝质量不错。安装挺方便的。只要有大屏的导航系统。导航系统必须要有USB接头才可以的。我买的...
# 1      1  记录仪安装车上，很上档次很好看，送了很多东西，哈哈，主要是记录仪太清晰了，比我原来的清楚多了...
# 2      1  记录仪像个智障，都设置好了，ADAS却不提示，只能提示前车启动请注意。当个普通记录仪用吧，拍...
# 3      1  行车记录仪安装好，线隐蔽成功很美观，开机使用只有高清导航，经咨询升级后电子狗，ADAS都能用...
# 4      1        效果还可以吧，时间只能显示在右上方，白天看不到时间，晚上录制有点曝光了，车牌拍不太清楚
# 5      1                         宝贝，不错，收到之后立马装上了，像素清晰度都挺好的。
# 6      1                                   功能齐全 设定安装简单 物超所值
# 7      1         收到宝贝。真的很不错。物流特别快。摄像头特别清晰。看起来特别高大上。最满意的一次网购
# 8      1                   东西很好也很清晰，功能也很全，很实用，像素也很好，晚上也看的清楚
# 9      1             东西挺好，比原来车上的清楚多了！操作也比较简单！给个赞！自己动手十分钟搞定！
# 10     1                          宝贝不错，就是打开应用有点延时，这个价位应该可以。
# 11     1    宝贝收到了很不错，虽然在安装后由于我这边的连接线要不得，卖家很快又给我发了一根，很不错的卖家。
# 12     1                        非常不错，挺好的，画面非常清晰，试了试，挺好，安装简便
# 13     1                                       便宜，实惠，广角比较满意
# 14     1                                   不错 清晰度可以 就是APP一般
# 15     1                                 宝贝收到，还没有安装，看着可以，满意
# 16     1                其它的功能都不错，可惜少了个移动侦测，有时候大屏不显示，要拔钥匙重开。
# 17     1               昨天自己亲手安装挺好安装的，东西挺好的，价格实惠，视频清晰，推荐大家购买
# 18     1            设计简洁实用，摄像头清晰，比我想象的要好！先好评！待后（不是我天天用！）追评！
# 19     1                                               摄像清晰
# 20    -1                          像素还可以，，功能都打开后非常的卡顿，根本就不能用
# 21     1                                      买过很多次了，老板值得信赖
# 22     1                                     质量很好物美价廉，清晰度很高
# 23     1                                    功能强大，图像清晰，非常满意！
# 24     1                                画面很清楚，安装跟简单，客服服务很好！
# 25     1                             给爸爸买的，收到后，就连接使用了，爸爸很满意
# 26     1                                            能用，一般般。
# 27     1  没有这个adas吧，挺想要的，有了吧，一直喊车道偏离，挺烦的&hellip;就这样吧，现在感...
# 28     1                                       还没装，不过看过去还可以
# 29     1                                     不挡视线，视频清晰，希望耐用
# ..   ...                                                ...
# 464    1                                         好装简单图像质量不错
# 465    1                                 还不错，就是在显示器上显示的有点卡帧
# 466    1                                           很好，却实不错。
# 467    1                                      货真价实，很好，给5星好评
# 468    1                                               效果很好
# 469    1                                             够用了，很好
# 470    1                                             还可以，清晰
# 471    1  录像还行，挺清晰，电子狗和adas不灵敏，电子狗很多地方摄像头都不报，adas.开机总提示校...
# 472    1                          东西不错，就是安装内存卡没有示意图，容易卡在里面！
# 473    1                                 很清晰 晚上效果也比我之前的好太多了
# 474    1                                               还没安装
# 475    1                                挺清楚的，感觉很好，还不占地方，赞一个
# 476    1                                   宝贝收到了画面清晰非常完美给五星
# 477   -2                                        15天内买家未作出评价
# 478    1  裝好了，之前有些功能不會用，詢問客服人員知道怎麼用了，很好值得推薦。用了几天前面攝像頭是10...
# 479    1  非常满意，自己的车有倒车影像了就想要一个隐藏式的，正合我的想法，而且特别清晰，本来想着买10...
# 480    1  这是真的很不错，商品如卖家描述一致，外形精美，价格实惠，应用方便！非常满意的一次购物，希望能...
# 481    1                                不错 挺好用 尤其 内存卡 不是杂牌子
# 482    1                                         此用户没有填写评价。
# 483    1                                         此用户没有填写评价。
# 484    1                                         此用户没有填写评价。
# 485    1                                         此用户没有填写评价。
# 486    1                                 评价方未及时做出评价,系统默认好评!
# 487    1                                 评价方未及时做出评价,系统默认好评!
# 488    1                                 评价方未及时做出评价,系统默认好评!
# 489    1                                 评价方未及时做出评价,系统默认好评!
# 490    1                                 评价方未及时做出评价,系统默认好评!
# 491    1                                         此用户没有填写评价。
# 492    1                                 评价方未及时做出评价,系统默认好评!
# 493    1                                 评价方未及时做出评价,系统默认好评!
#
#               rateDate  users
# 0    2018年07月09日 09:23  奋***6
#     第 9/ 9页 第2/220个商品
#     总评论123条，可获取7页
#     第 7/ 7页 第3/220个商品
#     总评论302条，可获取16页
#     第16/16页 22.84105348587036

# %%
len(result[1])
# Out:
# 123

# %%
# Out:
# 'https://detail.tmall.com/item.htm?id=568779667283'

# %%
# Out:
#     总评论132条，可获取7页
#     第 7/ 7页
#     appendComment_commentTime  \
# 0         2018-07-10 22:09:05
# 1                        None
# 2                        None
# 3                        None
# 4                        None
# 5                        None
# 6                        None
# 7                        None
# 8                        None
# 9                        None
# 10                       None
# 11                       None
# 12                       None
# 13                       None
# 14                       None
# 15                       None
# 16                       None
# 17                       None
# 18                       None
# 19                       None
# 20                       None
# 21                       None
# 22                       None
# 23                       None
# 24                       None
# 25                       None
# 26                       None
# 27                       None
# 28                       None
# 29                       None
# ..                        ...
# 102       2018-06-06 22:41:19
# 103                      None
# 104       2018-06-12 20:37:54
# 105       2018-06-04 02:41:51
# 106       2018-07-07 11:33:31
# 107                      None
# 108                      None
# 109                      None
# 110                      None
# 111                      None
# 112                      None
# 113                      None
# 114                      None
# 115       2018-06-13 09:03:31
# 116       2018-06-07 18:13:39
# 117                      None
# 118                      None
# 119                      None
# 120                      None
# 121                      None
# 122                      None
# 123                      None
# 124                      None
# 125                      None
# 126                      None
# 127       2018-07-04 22:18:23
# 128                      None
# 129       2018-07-06 11:59:05
# 130                      None
# 131                      None
#
#                                  appendComment_content  appendComment_days  \
# 0                                 大骗子 发来的摄像头跟照片完全是两个东西                 1.0
# 1                                                 None                 NaN
# 2                                                 None                 NaN
# 3                                                 None                 NaN
# 4                                                 None                 NaN
# 5                                                 None                 NaN
# 6                                                 None                 NaN
# 7                                                 None                 NaN
# 8                                                 None                 NaN
# 9                                                 None                 NaN
# 10                                                None                 NaN
# 11                                                None                 NaN
# 12                                                None                 NaN
# 13                                                None                 NaN
# 14                                                None                 NaN
# 15                                                None                 NaN
# 16                                                None                 NaN
# 17                                                None                 NaN
# 18                                                None                 NaN
# 19                                                None                 NaN
# 20                                                None                 NaN
# 21                                                None                 NaN
# 22                                                None                 NaN
# 23                                                None                 NaN
# 24                                                None                 NaN
# 25                                                None                 NaN
# 26                                                None                 NaN
# 27                                                None                 NaN
# 28                                                None                 NaN
# 29                                                None                 NaN
# ..                                                 ...                 ...
# 102                                           非常好 功能齐全                 3.0
# 103                                               None                 NaN
# 104  经过店主细致讲解，联网升级版本后，其它功能才能够使用。之前因为没有升级所以没有看到其它功能，...                 0.0
# 105                                             卖家服务很好                14.0
# 106                 怎么样大家自己看，经常这样，大家想想关键时刻如果这样要这个有什么用?                20.0
# 107                                               None                 NaN
# 108                                               None                 NaN
# 109                                               None                 NaN
# 110                                               None                 NaN
# 111                                               None                 NaN
# 112                                               None                 NaN
# 113                                               None                 NaN
# 114                                               None                 NaN
# 115                              什么偏离提醒都没有设置里面也弄过了还是没有                 2.0
# 116  再忙也要來追評，想不到這個價錢可以買到這麼強大的記錄儀，清晣度非常滿意，還有電子狗定位也准確...                 4.0
# 130            东西安装方便，自己安装，调试搞定，好评 东西安装方便，自己安装，调试搞定，好评  2018-07-03 00:13:38
# 131                                         此用户没有填写评论!  2018-06-07 13:54:51
#
#      users
# 0    l***9
# 1    水***伊
# 2    碧***8
# 3    东***页
# 4    今***9
# 5    t***1
# 6    3***天
# 7    t***2
# 8    心***6
# 9    t***5
# 10   我***4
# 11   t***2
# 12   t***6
# 13   冯***贝
# 14   业***安
# 15   w***1
# 16   宇***家
# 17   若***5
# 18   h***4
# 19   w***6
# 20   t***7
# 21   h***c
# 22   梁***5
# 23   飞***了
# 24   胶***捷
# 25   k***9
# 26   邓***5
# 27   f***9
# 28   w***浩
# 29   兔***丸
# ..     ...
# 102  l***j
# 103  黑***7
# 104  一***2
# 105  郑***y
# 106  d***7
# 107  枫***宝
# 108  z***4
# 109  白***4
# 110  y***9
# 111  l***话
# 112  l***丫
# 113  9***小
# 114  y***j
# 115  生***3
# 116  s***洪
# 117  申***我
# 118  徐***序
# 119  许***路
# 120  戒***啊
# 121  l***3
# 122  宝***2
# 123  t***5
# 124  高***法
# 125  放***舞
# 126  z***2
# 127  猴***的
# 128  g***t
# 129  李***丫
# 130  s***1
# 131  h***5
#
# [132 rows x 6 columns]

# %%
#并行
texturls = urls
coms =[]
time3 =time.time()
pool = Pool(8)
coms=pool.map(getitemcom,texturls)
pool.close()
pool.join()
time4 =time.time()
print(str(time4-time3))
# Out:
#     总评论21条，可获取2页
#     总评论182条，可获取10页
#     总评论171条，可获取9页
#     总评论96条，可获取5页
#     总评论301条，可获取16页
#     总评论41条，可获取3页
#     总评论17条，可获取1页
#     总评论267条，可获取14页
#     总评论66条，可获取4页
#     总评论0条，可获取0页
#     总评论3条，可获取1页
#     总评论32条，可获取2页
#     总评论12条，可获取1页
#     总评论152条，可获取8页
#     总评论50条，可获取3页
#     总评论9条，可获取1页
#     总评论25条，可获取2页
#     总评论63条，可获取4页
#     总评论123条，可获取7页
#     总评论79条，可获取4页
#     总评论795条，可获取40页
#     总评论792条，可获取40页
#     总评论1202条，可获取61页
#     总评论44条，可获取3页
#     总评论31条，可获取2页
#     总评论158条，可获取8页
#     总评论615条，可获取31页
#     总评论302条，可获取16页
#     总评论18条，可获取1页
#     总评论21条，可获取2页
#     总评论18条，可获取1页
#     总评论7条，可获取1页
#     总评论89条，可获取5页
#     总评论250条，可获取13页
#     总评论49条，可获取3页
#     总评论12条，可获取1页
#     总评论59条，可获取3页
#     总评论54条，可获取3页
#     总评论24条，可获取2页
#     总评论5条，可获取1页
#     总评论263条，可获取14页
#     总评论15条，可获取1页
#     总评论7条，可获取1页
#     总评论307条，可获取16页
#     总评论4条，可获取1页
#     总评论73条，可获取4页
#     总评论7条，可获取1页
#     总评论12条，可获取1页
#     总评论3条，可获取1页
#     总评论11条，可获取1页
#     总评论2条，可获取1页
#     总评论8条，可获取1页
#     总评论26条，可获取2页
#     总评论7条，可获取1页
#     总评论324条，可获取17页
#     总评论10条，可获取1页
#     总评论11条，可获取1页
#     总评论247条，可获取13页
#     总评论15条，可获取1页
#     总评论12条，可获取1页
#     总评论7条，可获取1页
#     总评论3条，可获取1页
#     总评论9条，可获取1页
#     总评论63条，可获取4页
#     总评论1条，可获取1页
#     总评论347条，可获取18页
#     总评论29条，可获取2页
#     总评论512条，可获取26页
#     总评论16条，可获取1页
#     总评论2条，可获取1页
#     总评论91条，可获取5页
#     总评论5条，可获取1页
#     总评论5条，可获取1页
#     总评论19条，可获取1页
#     总评论60条，可获取3页
#     总评论5条，可获取1页
#     总评论242条，可获取13页
#     总评论21条，可获取2页
#     总评论231条，可获取12页
#     总评论26条，可获取2页
#     总评论27条，可获取2页
#     总评论317条，可获取16页
#     总评论155条，可获取8页
#     总评论21条，可获取2页
#     总评论56条，可获取3页
#     总评论2970条，可获取99页
#     总评论4条，可获取1页
#     总评论29条，可获取2页
#     总评论2条，可获取1页
#     总评论140条，可获取7页
#     总评论3条，可获取1页
#     总评论22条，可获取2页
#     总评论108条，可获取6页
#     总评论15条，可获取1页
#     总评论6条，可获取1页
#     总评论7条，可获取1页
#     总评论2条，可获取1页
#     总评论0条，可获取0页
#     第 3/ 6页 获取4页
#     总评论18条，可获取1页
#     总评论6条，可获取1页
#     总评论242条，可获取13页
#     总评论45条，可获取3页
#     总评论3条，可获取1页
#     总评论3条，可获取1页
#     总评论1条，可获取1页
#     总评论21条，可获取2页
#     总评论13条，可获取1页
#     总评论1条，可获取1页
#     总评论14条，可获取1页
#     总评论9条，可获取1页
#     总评论1条，可获取1页
#     总评论19条，可获取1页
#     总评论17条，可获取1页
#     总评论1条，可获取1页
#     总评论54条，可获取3页
#     总评论20条，可获取1页
#     总评论2条，可获取1页
#     总评论1条，可获取1页
#     总评论11条，可获取1页
#     总评论8条，可获取1页
#     总评论0条，可获取0页
#     总评论0条，可获取0页
#     总评论4条，可获取1页
#     总评论21条，可获取2页
#     总评论8条，可获取1页
#     总评论1条，可获取1页
#     总评论5条，可获取1页
#     总评论28条，可获取2页
#     总评论15条，可获取1页
#     总评论0条，可获取0页
#     总评论4条，可获取1页
#     总评论2条，可获取1页
#     总评论1条，可获取1页
#     总评论217条，可获取11页
#     总评论4条，可获取1页
#     总评论0条，可获取0页
#     总评论1条，可获取1页
#     总评论0条，可获取0页
#     总评论13条，可获取1页
#     总评论2条，可获取1页
#     总评论1条，可获取1页
#     总评论10条，可获取1页
#     总评论2条，可获取1页
#     总评论141条，可获取8页
#     总评论12条，可获取1页
#     总评论1条，可获取1页
#     总评论173条，可获取9页
#     总评论3条，可获取1页
#     总评论4条，可获取1页
#     总评论15条，可获取1页
#     总评论0条，可获取0页
#     总评论1条，可获取1页
#     总评论3条，可获取1页
#     总评论1条，可获取1页
#     总评论1条，可获取1页
#     总评论11条，可获取1页
#     总评论44条，可获取3页
#     总评论0条，可获取0页
#     总评论6条，可获取1页
#     总评论3条，可获取1页
#     总评论1条，可获取1页
#     总评论1条，可获取1页
#     总评论0条，可获取0页
#     总评论0条，可获取0页
#     总评论2条，可获取1页
#     总评论2条，可获取1页
#     总评论5条，可获取1页
#     总评论9条，可获取1页
#     总评论3条，可获取1页
#     总评论0条，可获取0页
#     总评论55条，可获取3页
#     总评论1条，可获取1页
#     总评论2条，可获取1页
#     总评论0条，可获取0页
#     总评论2条，可获取1页
#     总评论101条，可获取6页
#     总评论1条，可获取1页
#     总评论1条，可获取1页
#     总评论1条，可获取1页
#     总评论1条，可获取1页
#     总评论0条，可获取0页
#     总评论4条，可获取1页
#     总评论2条，可获取1页
#     总评论6条，可获取1页
#     总评论4条，可获取1页
#     总评论0条，可获取0页
#     总评论1条，可获取1页
#     总评论11条，可获取1页
#     总评论0条，可获取0页
#     总评论1条，可获取1页
#     总评论0条，可获取0页
#     总评论3条，可获取1页
#     总评论2条，可获取1页
#     总评论3条，可获取1页
#     总评论3条，可获取1页
#     总评论2条，可获取1页
#     总评论6条，可获取1页
#     总评论17条，可获取1页
#     总评论2条，可获取1页
#     总评论3条，可获取1页
#     总评论6条，可获取1页
#     总评论5条，可获取1页
#     总评论0条，可获取0页
#     总评论0条，可获取0页
#     总评论1条，可获取1页
#     总评论9条，可获取1页
#     总评论30条，可获取2页
#     总评论50条，可获取3页
#     总评论0条，可获取0页
#     总评论29条，可获取2页
#     总评论0条，可获取0页
#     总评论4条，可获取1页
#     总评论3条，可获取1页
#     总评论3条，可获取1页
#     总评论10条，可获取1页
#     总评论0条，可获取0页
#     总评论14条，可获取1页
#     总评论116条，可获取6页
#     总评论28条，可获取2页
#     第 2/ 2页 134.76706266403198

# %%
final = []
for i in coms:
    if len(i)!=0:
        final.append(i)

# %%
len(final)
# Out:
# 198

# %%
totcoms = pd.concat(final,axis=0,ignore_index=True)

# %%
totcoms
# Out:
#       appendComment_commentTime  \
# 0                          None
# 1                          None
# 2                          None
# 3                          None
# 4           2018-07-05 17:09:18
# 5                          None
# 6                          None
# 7                          None
# 8                          None
# 9                          None
# 10                         None
# 11                         None
# 12                         None
# 13                         None
# 14                         None
# 15                         None
# 16          2018-06-27 09:03:07
# 17                         None
# 18                         None
# 19                         None
# 20                         None
# 21                         None
# 22                         None
# 23                         None
# 24                         None
# 25                         None
# 26                         None
# 27                         None
# 28                         None
# 29                         None
# ...                         ...
# 14091                      None
# 14092                      None
# 14093       2018-02-21 21:27:17
# 14094                      None
# 14095                      None
# 14096       2018-04-03 17:10:47
# 14097                      None
# 14098                      None
# 14099                      None
# 14100                      None
# 14101       2018-03-03 12:08:59
# 14102       2018-05-22 17:17:13
# 14103                      None
# 14104                      None
# 14105       2018-06-22 10:56:01
# 14106       2018-06-15 11:59:50
# 14107                      None
# 14108                      None
# 14109                      None
# 14110                      None
# 14111                      None
# 14112                      None
# 14113                      None
# 14114                      None
# 14115                      None
# 14116                      None
# 14117                      None
# 14118                      None
# 14119                      None
# 14120                      None
#
#                                    appendComment_content  appendComment_days  \
# 0                                                   None                 NaN
# 1                                                   None                 NaN
# 2                                                   None                 NaN
# 3                                                   None                 NaN
# 4                                     大家千万不要上当了，，东西太垃圾了，                 2.0
# 5                                                   None                 NaN
# 6                                                   None                 NaN
# 7                                                   None                 NaN
# 8                                                   None                 NaN
# 9                                                   None                 NaN
# 10                                                  None                 NaN
# 11                                                  None                 NaN
# 12                                                  None                 NaN
# 13                                                  None                 NaN
# 14                                                  None                 NaN
# 15                                                  None                 NaN
# 16                                             质量不错，非常好用                 0.0
# 17                                                  None                 NaN
# 18                                                  None                 NaN
# 19                                                  None                 NaN
# 20                                                  None                 NaN
# 21                                                  None                 NaN
# 22                                                  None                 NaN
# 23                                                  None                 NaN
# 24                                                  None                 NaN
# 25                                                  None                 NaN
# 26                                                  None                 NaN
# 27                                                  None                 NaN
# 28                                                  None                 NaN
# 29                                                  None                 NaN
# ...                                                  ...                 ...
# 14091                                               None                 NaN
# 14092                                               None                 NaN
# 14093  用了段时间这款云镜必须表扬下，这次出差全靠有它，一路到达目的地没有耽误一点时间，导航很准确，...                21.0
# 14094                                               None                 NaN
# 14095                                               None                 NaN
# 14096  大家不要买这款这么贵的行车记录仪，我花了1700元买这个产品，用不到一个月，问题百出，什么远...                24.0
# 14097                                               None                 NaN
# 14098                                               None                 NaN
# 14099                                               None                 NaN
# 14100                                               None                 NaN
# 14101                              该评价含有他人敏感信息或辱骂等不当评价内容                22.0
# 14102    机子还行，流量真无力吐槽了，充2G到账1200兆，打客服要么不接给你挂断，要么各种理由搪塞你。                95.0
# 14103                                               None                 NaN
# 14104                                               None                 NaN
# 14105                                    不行啊，自动关机开机用不成呀！                15.0
# 14106                          用了个把月了，还不错，挺流畅的，功能也全非常实用！                15.0
# 14107                                               None                 NaN
# 14108                                               None                 NaN
# 14109                                               None                 NaN
# 14110                                               None                 NaN
# 14111                                               None                 NaN
# 14112                                               None                 NaN
# 14113                                               None                 NaN
# 14114                                               None                 NaN
# 14115                                               None                 NaN
# 14116                                               None                 NaN
# 14117                                               None                 NaN
# 14118                                               None                 NaN
# 14119                                               None                 NaN
# 14120                                               None                 NaN
#
#                                              rateContent             rateDate  \
# 0      记录仪安装车上，很上档次很好看，送了很多东西，哈哈，主要是记录仪太清晰了，比我原来的清楚多了...  2018-06-28 20:19:03
# 1      行车记录仪安装好，线隐蔽成功很美观，开机使用只有高清导航，经咨询升级后电子狗，ADAS都能用...  2018-07-07 15:46:47
# 2                              宝贝不错，就是打开应用有点延时，这个价位应该可以。  2018-07-07 17:54:56
# 3                                     宝贝收到，还没有安装，看着可以，满意  2018-07-04 18:30:25
# 4                              像素还可以，，功能都打开后非常的卡顿，根本就不能用  2018-07-03 09:18:08
# 5             收到宝贝。真的很不错。物流特别快。摄像头特别清晰。看起来特别高大上。最满意的一次网购  2018-06-30 15:08:11
# 6                       东西很好也很清晰，功能也很全，很实用，像素也很好，晚上也看的清楚  2018-06-30 11:06:11
# 7                    其它的功能都不错，可惜少了个移动侦测，有时候大屏不显示，要拔钥匙重开。  2018-07-07 17:13:45
